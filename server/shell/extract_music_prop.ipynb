# %%
import librosa
import sklearn
import pandas as pd
import time
import os

# %%
### 초기 설정

ROOT = "./data/Dataset"    # 데이터셋이 존재하는 폴더의 경로 지정
LIMIT_CNT = 70    # 분석할 음악 개수(None: "제한없음" / 50:" 장르별 50곡 제한")

# %%
### 속성 추출 함수

def extract_music_prop(filename = None, genre = None):
    path = f"{ROOT}/{genre}/{filename}"
    audio_info = [None for _ in range(len(audio_header))]
    y, sr = librosa.load(path)
    y, _ = librosa.effects.trim(y=y)
    length = int(len(y) / sr)
    chromagram = librosa.feature.chroma_stft(y=y, sr=sr, hop_length=512)
    rmsTest = librosa.feature.rms(y=y)
    spectral_centroids = librosa.feature.spectral_centroid(y=y, sr=sr)[0]
    spectral_bandwidth = librosa.feature.spectral_bandwidth(y=y, sr=sr)[0]
    rolloffTest = librosa.feature.spectral_rolloff(y=y, sr=sr)
    rolloffTest.mean()
    rolloffTest.var()
    zero_crossings = librosa.zero_crossings(y=y, pad=False)
    y_harm, y_perc = librosa.effects.hpss(y=y)
    tempo, _ = librosa.beat.beat_track(y=y, sr=sr)
    
    audio_info[0] = filename
    audio_info[1] = length
    audio_info[2] = chromagram.mean() 
    audio_info[3] = chromagram.var()
    audio_info[4] = rmsTest.mean()
    audio_info[5] = rmsTest.var()
    audio_info[6] = spectral_centroids.mean()
    audio_info[7] = spectral_centroids.var()
    audio_info[8] = spectral_bandwidth.mean()
    audio_info[9] = spectral_bandwidth.var()
    audio_info[10] = rolloffTest.mean()
    audio_info[11] = rolloffTest.var()
    audio_info[12] = zero_crossings.mean()
    audio_info[13] = zero_crossings.var()
    audio_info[14] = y_harm.mean()
    audio_info[15] = y_harm.var()
    audio_info[16] = y_perc.mean()
    audio_info[17] = y_perc.var()
    audio_info[18] = tempo

    def normalize(x, axis=0):
        return sklearn.preprocessing.minmax_scale(x, axis=axis)
    mfccs = librosa.feature.mfcc(y=y, sr=sr)
    mfccs = normalize(mfccs, axis=1)

    for i in range(19, 59, 2):
        idx = int((i - 18) / 2)
        audio_info[i] = mfccs[idx].mean()
        audio_info[1 + i] = mfccs[idx].var()
        
    audio_info[59] = genre
    return audio_info

# %%
### 음악에서 추출할 속성명(csv파일 헤더)
# 데이터프레임 생성

audio_header = ["filename", "length", "chroma_stft_mean", "chroma_stft_var", "rms_mean", "rms_var",
                "spectral_centroid_mean", "spectral_centroid_var", "spectral_bandwidth_mean", "spectral_bandwidth_var",
                "rolloff_mean", "rolloff_var", "zero_crossing_rate_mean", "zero_crossing_rate_var", "harmony_mean",
                "harmony_var", "perceptr_mean", "perceptr_var", "tempo", "mfcc1_mean", "mfcc1_var", "mfcc2_mean",
                "mfcc2_var", "mfcc3_mean", "mfcc3_var", "mfcc4_mean", "mfcc4_var", "mfcc5_mean", "mfcc5_var",
                "mfcc6_mean", "mfcc6_var", "mfcc7_mean", "mfcc7_var", "mfcc8_mean", "mfcc8_var", "mfcc9_mean",
                "mfcc9_var", "mfcc10_mean", "mfcc10_var", "mfcc11_mean", "mfcc 11_var", "mfcc12_mean", "mfcc12_var",
                "mfcc13_mean", "mfcc13_var", "mfcc14_mean", "mfcc14_var", "mfcc15_mean", "mfcc15_var", "mfcc16_mean",
                "mfcc16_var", "mfcc17_mean", "mfcc17_var", "mfcc18_mean", "mfcc18_var", "mfcc19_mean", "mfcc19_var",
                "mfcc20_mean", "mfcc20_var", "label"]
audio_df = pd.DataFrame([], audio_header).T

# %%
### 폴더 구조 파악
# "./data/Dataset"에 만들어진 폴더명으로 장르 구분
# 폴더내의 wav 파일명 가져오기

file_genre_list = os.listdir(ROOT)
genre_dict = {}

for genre in file_genre_list:
    file_name_list = os.listdir(f"./data/Dataset/{genre}")
    genre_dict[genre] = file_name_list

# %%
### 음악 분석 시작

total_start_time = time.time()
print("[Log] 음악 분석 시작...")
for genre in genre_dict:
    for i, filename in enumerate(genre_dict[genre]):
        if LIMIT_CNT and LIMIT_CNT <= i: continue
        start_time = time.time()
        try:
            audio_info = extract_music_prop(filename, genre)
            audio_df.loc[filename] = audio_info
            print(f"[Log] {genre} {i + 1}번째 곡 소요시간:{time.time() - start_time: .1f}s")
        except:
            print("[Error] {genre} {i + 1}번째 곡 분석 실패")

print(f"[LOG] 전체 분석 소요시간:{time.time() - total_start_time: .1f}s")
# Out:
# [Log] 음악 분석 시작...
# [Log] ballad 1번째 곡 소요시간: 16.1s
# [Log] ballad 2번째 곡 소요시간: 14.2s
# [Log] ballad 3번째 곡 소요시간: 14.7s
# [Log] ballad 4번째 곡 소요시간: 14.3s
# [Log] ballad 5번째 곡 소요시간: 14.5s
# [Log] ballad 6번째 곡 소요시간: 17.6s
# [Log] ballad 7번째 곡 소요시간: 13.8s
# [Log] ballad 8번째 곡 소요시간: 14.2s
# [Log] ballad 9번째 곡 소요시간: 15.4s
# [Log] ballad 10번째 곡 소요시간: 13.2s
# [Log] ballad 11번째 곡 소요시간: 13.4s
# [Log] ballad 12번째 곡 소요시간: 14.7s
# [Log] ballad 13번째 곡 소요시간: 10.8s
# [Log] ballad 14번째 곡 소요시간: 18.7s
# [Log] ballad 15번째 곡 소요시간: 13.1s
# [Log] ballad 16번째 곡 소요시간: 13.7s
# [Log] ballad 17번째 곡 소요시간: 13.7s
# [Log] ballad 18번째 곡 소요시간: 18.7s
# [Log] ballad 19번째 곡 소요시간: 14.3s
# [Log] ballad 20번째 곡 소요시간: 15.5s
# [Log] ballad 21번째 곡 소요시간: 18.0s
# [Log] ballad 22번째 곡 소요시간: 12.0s
# [Log] ballad 23번째 곡 소요시간: 15.8s
# [Log] ballad 24번째 곡 소요시간: 13.0s
# [Log] ballad 25번째 곡 소요시간: 14.5s
# [Log] ballad 26번째 곡 소요시간: 12.8s
# [Log] ballad 27번째 곡 소요시간: 14.4s
# [Log] ballad 28번째 곡 소요시간: 13.9s
# [Log] ballad 29번째 곡 소요시간: 16.5s
# [Log] ballad 30번째 곡 소요시간: 12.7s
# [Log] ballad 31번째 곡 소요시간: 15.5s
# [Log] ballad 32번째 곡 소요시간: 16.7s
# [Log] ballad 33번째 곡 소요시간: 14.5s
# [Log] ballad 34번째 곡 소요시간: 14.4s
# [Log] ballad 35번째 곡 소요시간: 15.6s
# [Log] ballad 36번째 곡 소요시간: 16.3s
# [Log] ballad 37번째 곡 소요시간: 11.6s
# [Log] ballad 38번째 곡 소요시간: 15.5s
# [Log] ballad 39번째 곡 소요시간: 14.4s
# [Log] ballad 40번째 곡 소요시간: 10.4s
# [Log] ballad 41번째 곡 소요시간: 17.7s
# [Log] ballad 42번째 곡 소요시간: 15.1s
# [Log] ballad 43번째 곡 소요시간: 14.8s
# [Log] ballad 44번째 곡 소요시간: 12.8s
# [Log] ballad 45번째 곡 소요시간: 13.7s
# [Log] ballad 46번째 곡 소요시간: 12.4s
# [Log] ballad 47번째 곡 소요시간: 15.8s
# [Log] ballad 48번째 곡 소요시간: 14.2s
# [Log] ballad 49번째 곡 소요시간: 14.6s
# [Log] ballad 50번째 곡 소요시간: 14.5s
# [Log] ballad 51번째 곡 소요시간: 17.9s
# [Log] ballad 52번째 곡 소요시간: 12.9s
# [Log] ballad 53번째 곡 소요시간: 12.1s
# [Log] ballad 54번째 곡 소요시간: 14.5s
# [Log] ballad 55번째 곡 소요시간: 17.1s
# [Log] ballad 56번째 곡 소요시간: 17.9s
# [Log] ballad 57번째 곡 소요시간: 15.6s
# [Log] ballad 58번째 곡 소요시간: 13.1s
# [Log] ballad 59번째 곡 소요시간: 12.4s
# [Log] ballad 60번째 곡 소요시간: 13.7s
# [Log] ballad 61번째 곡 소요시간: 16.5s
# [Log] ballad 62번째 곡 소요시간: 15.2s
# [Log] ballad 63번째 곡 소요시간: 13.2s
# [Log] ballad 64번째 곡 소요시간: 11.4s
# [Log] ballad 65번째 곡 소요시간: 13.2s
# [Log] ballad 66번째 곡 소요시간: 13.5s
# [Log] ballad 67번째 곡 소요시간: 15.1s
# [Log] ballad 68번째 곡 소요시간: 13.8s
# [Log] ballad 69번째 곡 소요시간: 14.2s
# [Log] ballad 70번째 곡 소요시간: 14.6s
# [Log] dance 1번째 곡 소요시간: 12.2s
# [Log] dance 2번째 곡 소요시간: 11.3s
# [Log] dance 3번째 곡 소요시간: 11.4s
# [Log] dance 4번째 곡 소요시간: 13.1s
# [Log] dance 5번째 곡 소요시간: 13.4s
# [Log] dance 6번째 곡 소요시간: 10.5s
# [Log] dance 7번째 곡 소요시간: 12.5s
# [Log] dance 8번째 곡 소요시간: 11.0s
# [Log] dance 9번째 곡 소요시간: 11.9s
# [Log] dance 10번째 곡 소요시간: 13.2s
# [Log] dance 11번째 곡 소요시간: 13.0s
# [Log] dance 12번째 곡 소요시간: 11.9s
# [Log] dance 13번째 곡 소요시간: 12.2s
# [Log] dance 14번째 곡 소요시간: 14.5s
# [Log] hiphop 2번째 곡 소요시간: 14.2s
# [Log] hiphop 3번째 곡 소요시간: 6.0s
# [Log] hiphop 4번째 곡 소요시간: 13.1s
# [Log] hiphop 5번째 곡 소요시간: 14.9s
# [Log] hiphop 6번째 곡 소요시간: 14.2s
# [Log] hiphop 7번째 곡 소요시간: 12.9s
# [Log] hiphop 8번째 곡 소요시간: 11.6s
# [Log] hiphop 9번째 곡 소요시간: 14.2s
# [Log] hiphop 10번째 곡 소요시간: 16.2s
# [Log] hiphop 11번째 곡 소요시간: 11.7s
# [Log] hiphop 12번째 곡 소요시간: 14.8s
# [Log] hiphop 13번째 곡 소요시간: 17.4s
# [Log] hiphop 14번째 곡 소요시간: 14.2s
# [Log] hiphop 15번째 곡 소요시간: 12.6s
# [Log] hiphop 16번째 곡 소요시간: 11.8s
# [Log] hiphop 17번째 곡 소요시간: 10.7s
# [Log] hiphop 18번째 곡 소요시간: 11.9s
# [Log] hiphop 19번째 곡 소요시간: 14.8s
# [Log] hiphop 20번째 곡 소요시간: 60.5s
# [Log] hiphop 21번째 곡 소요시간: 19.1s
# [Log] hiphop 22번째 곡 소요시간: 18.2s
# [Log] hiphop 23번째 곡 소요시간: 14.9s
# [Log] hiphop 24번째 곡 소요시간: 8.5s
# [Log] hiphop 25번째 곡 소요시간: 11.3s
# [Log] hiphop 26번째 곡 소요시간: 12.9s
# [Log] hiphop 27번째 곡 소요시간: 19.3s
# [Log] hiphop 28번째 곡 소요시간: 13.8s
# [Log] hiphop 29번째 곡 소요시간: 13.9s
# [Log] hiphop 30번째 곡 소요시간: 14.6s
# [Log] hiphop 31번째 곡 소요시간: 38.5s
# [Log] hiphop 32번째 곡 소요시간: 13.7s
# [Log] hiphop 33번째 곡 소요시간: 13.1s
# [Log] hiphop 34번째 곡 소요시간: 15.4s
# [Log] hiphop 35번째 곡 소요시간: 15.1s
# [Log] hiphop 36번째 곡 소요시간: 18.4s
# [Log] hiphop 37번째 곡 소요시간: 13.7s
# [Log] hiphop 38번째 곡 소요시간: 12.1s
# [Log] hiphop 39번째 곡 소요시간: 14.9s
# [Log] hiphop 40번째 곡 소요시간: 9.2s
# [Log] hiphop 41번째 곡 소요시간: 18.3s
# [Log] hiphop 42번째 곡 소요시간: 13.2s
# [Log] hiphop 43번째 곡 소요시간: 14.0s
# [Log] hiphop 44번째 곡 소요시간: 13.6s
# [Log] hiphop 45번째 곡 소요시간: 14.2s
# [Log] hiphop 46번째 곡 소요시간: 12.8s
# [Log] hiphop 47번째 곡 소요시간: 11.7s
# [Log] hiphop 48번째 곡 소요시간: 13.5s
# [Log] hiphop 49번째 곡 소요시간: 12.5s
# [Log] hiphop 50번째 곡 소요시간: 12.7s

# %%
# 분석 결과 확인

audio_df

# %%
# CSV 생성

audio_df.set_index(keys=['filename'], inplace=True, drop=True)
audio_df.to_csv("extract_music_prop_" + str(int(time.time())) + ".csv")
